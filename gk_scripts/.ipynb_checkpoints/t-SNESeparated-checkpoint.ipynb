# %%
from yellowbrick.text import TSNEVisualizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
va_split = pd.read_csv('../../DataPlus/va_split.csv')
dvd_split = pd.read_csv('../../DataPlus/dvd_split.csv')

# %%
def tsne(df, var, docs):
    tsne = TSNEVisualizer()
    
    # drops examples with NA for var of interest
    drop_df = df.dropna(subset=[var])
    labels = drop_df[var]
    
    # fit and visualize
    tsne.fit(docs, labels)
    tsne.poof()

# %%
va_df = va_split.dropna(subset=['Convo_1'])
va_tfidf = TfidfVectorizer()
va_docs = va_tfidf.fit_transform(va_df['Convo_1'])

# %%
dvd_df = dvd_split.dropna(subset=['Convo_1'])
dvd_tfidf = TfidfVectorizer()
dvd_docs = dvd_tfidf.fit_transform(dvd_df['Convo_1'])

# %%
tsne(va_df, 'txgot_binary', va_docs)

# %%
tsne(dvd_df, 'txgot_binary', dvd_docs)

# %% [markdown]
# The VA dataset seems to have distinct clusters of documents but DVD is more homogenous.
