# %% [markdown]
# # Feature Choice

# %% [markdown]
# Now that we've separated the datasets, we have more freedom in feature choice because we are not constrained by variables that are shared by the datasets.

# %%
import pandas as pd

# %%
va_original = pd.read_csv('../../DataPlus/data/VA_original.csv')
dvd_original = pd.read_csv('../../DataPlus/data/DVD_original.csv')

# %%
list(va_original.columns)
# Out:
# ['Unnamed: 0',
#  'ID',
#  'MD',
#  'Ch_IL',
#  'RadOnc_apt',
#  'ActiveSurveillance',
#  'Surgery',
#  'Radiation',
#  'Brachy',
#  'Recom',
#  'txgot',
#  'TxgotT3prefcc',
#  'TxgotTx3cc',
#  'TxStrongRec',
#  'PtReqRec',
#  't3txpref',
#  'Finaltx3',
#  'Tx3',
#  'Txsec3',
#  'Txother3',
#  'Txlean3',
#  'Txleansec3',
#  'Ch3_comb',
#  'SDM3',
#  'Aware3',
#  'Opinion3',
#  'Ask3',
#  'Info3',
#  'Explain3',
#  'Easyund3',
#  'Adv3',
#  'Disadv3',
#  'Decide3',
#  'Involve3',
#  'Satis3',
#  'Agree3',
#  'Discuss3',
#  'Satdec3',
#  'Sure3',
#  'Inform3',
#  'Clear3',
#  'Awaretx3',
#  'Informtx3',
#  'Decimp3',
#  'Mdtxrec3',
#  'Whatrec3',
#  'Strongrec3',
#  'Recdec3',
#  'Talkda3',
#  'Whoda3',
#  'mdrespme',
#  'irespmd',
#  'mdtime',
#  'recmd',
#  'Mdask3',
#  'Mdexp3',
#  'Mdcause3',
#  'Mdtalk3',
#  'Mdopin3',
#  'Iasktx3',
#  'Iaskrec3',
#  'Idetail3',
#  'Iaskque3',
#  'Isugtx3',
#  'Iinsist3',
#  'Idoubt3',
#  'Iopinion3',
#  'Vatrust1',
#  'Vatrust2',
#  'Vatrust3',
# ...

# %%
list(dvd_original.columns)
# Out:
# ['Unnamed: 0',
#  'Act_t1_avg',
#  'Act_t2_avg',
#  'Act_t2_avg_mc',
#  'Act_t3_avg',
#  'Act_t3_tot',
#  'Actpt1_t1',
#  'Actpt1_t2',
#  'Actpt1_t3',
#  'Actpt2_t1',
#  'Actpt2_t2',
#  'Actpt2_t3',
#  'Actpt3_t1',
#  'Actpt3_t2',
#  'Actpt3_t3',
#  'Actpt4_t1',
#  'Actpt4_t2',
#  'Actpt4_t3',
#  'Anx11',
#  'Anx12',
#  'Anx13',
#  'Anx14',
#  'Anx15',
#  'Anx16',
#  'Anx21',
#  'Anx22',
#  'Anx23',
#  'Anx24',
#  'Anx25',
#  'Anx26',
#  'Anx31',
#  'Anx32',
#  'Anx33',
#  'Anx34',
#  'Anx35',
#  'Anx36',
#  'Anx41',
#  'Anx42',
#  'Anx43',
#  'Anx44',
#  'Anx45',
#  'Anx46',
#  'Anx47',
#  'Anx_t1_avg',
#  'Anx_t1_FS',
#  'Anx_t2_avg',
#  'Anx_t2_avg_mc',
#  'Anx_t2_FS',
#  'Anx_t3_avg',
#  'Anx_t3_FS',
#  'Anx_t4_AFS',
#  'Anx_t4_avg',
#  'Apt_speed',
#  'Apt_understand',
#  'Apt_understand_tell',
#  'Cancer_Gleason',
#  'Cancer_Gleason_dummy_6zero',
#  'Cancer_Gleason_dummy_7zero',
#  'Cancer_PCa',
#  'Cancer_psa',
#  'Cancer_Stage',
#  'Cancer1_EverPCa',
#  'Cancer2_KnowResult',
# ...

# %% [markdown]
# ## VA Features

# %% [markdown]
# ## DVD Features
